# %% [markdown]
# #                               PANDAS Learning Tutorial

# %%
people = {'First_Name': ['Prasanna', 'Mamauni', 'nityananda', 'Gugu','Shradha', 'Gopala', 'Divynashu','Sibu','Debu'],
          'Last_Name' : ['Sahoo', 'NaN', 'Sahoo', 'NaN', 'Sahoo', 'Sahoo','Samanta','Sahoo','Sahoo'],
          'Age': [30,30,65,10,12,25,12,2,2],
          'Place' :['Erlangen','Bangalore','Bhubaneswar','Nalco','Bhubaneswar','Sarikhi','Hyderbad','Kolkata','Nalco'],
          'Married' :['Yes','Yes','Yes','No','No','No','No','No','No']
        } 

print(people)
print(type(people))

# %%
import pandas as pd

people_DataFrame = pd.DataFrame(people)
people_DataFrame
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-6485851cf8fe> in <module>
#       1 import pandas as pd
#       2
# ----> 3 people_DataFrame = pd.DataFrame(people)
#       4 people_DataFrame
#
# NameError: name 'people' is not defined

# %%
people_DataFrame['Place']
# Out:
# 0       Erlangen
# 1      Bangalore
# 2    Bhubaneswar
# 3          Nalco
# 4    Bhubaneswar
# 5        Sarikhi
# 6       Hyderbad
# 7        Kolkata
# 8          Nalco
# Name: Place, dtype: object

# %%
print(type(people_DataFrame['Place']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
people_DataFrame.shape      # Attribute for finding the number or columns and rows for DF
# Out:
# (9, 5)

# %% [markdown]
# So dataframe is the collection of series.

# %% [markdown]
# ##  Maniplation of Columns in dataframe

# %%
people_DataFrame.columns
# Out:
# Index(['First_Name', 'Last_Name', 'Age', 'Place', 'Married'], dtype='object')

# %%
people_DataFrame[['Place', 'First_Name']]   # in oder to print desired columns need to create the a list
# Out:
#          Place  First_Name
# 0     Erlangen    Prasanna
# 1    Bangalore     Mamauni
# 2  Bhubaneswar  nityananda
# 3        Nalco        Gugu
# 4  Bhubaneswar     Shradha
# 5      Sarikhi      Gopala
# 6     Hyderbad   Divynashu
# 7      Kolkata        Sibu
# 8        Nalco        Debu

# %% [markdown]
# ## Manipulation of Rows in dataframe by
# 1. loc- Searching by labels
# 2. iloc- Searching by intigers

# %%
people_DataFrame.iloc[[1,2]]      # parsing the inex as a list
# Out:
#    First_Name Last_Name  Age        Place Married
# 1     Mamauni       NaN   30    Bangalore     Yes
# 2  nityananda     Sahoo   65  Bhubaneswar     Yes

# %%
people_DataFrame.iloc[[1,2], [2,3]]      # parsing the inex as a list
# Out:
#    Age        Place
# 1   30    Bangalore
# 2   65  Bhubaneswar

# %%
people_DataFrame.iloc[[1,2], [2]]
# Out:
#    Age
# 1   30
# 2   65

# %%
people_DataFrame.loc[[1,2], ['Place','Last_Name']]
# Out:
#          Place Last_Name
# 1    Bangalore       NaN
# 2  Bhubaneswar     Sahoo

# %%
people_DataFrame.loc[[0]]
# Out:
#   First_Name Last_Name  Age     Place Married
# 0   Prasanna     Sahoo   30  Erlangen     Yes

# %%
people_DataFrame.loc[ 0:1 ,'Last_Name':'Place'] # when using List slicing we don't use the inner list with[], just use the list slicing range
# Out:
#   Last_Name  Age      Place
# 0     Sahoo   30   Erlangen
# 1       NaN   30  Bangalore

# %%
people_DataFrame['Married'].value_counts()    # counts number of similarities
# Out:
# No     6
# Yes    3
# Name: Married, dtype: int64

# %% [markdown]
# ## Set, Reset and Use Indexes

# %%
people_DataFrame.index
# Out:
# RangeIndex(start=0, stop=9, step=1)

# %%
people_DataFrame.axes
# Out:
# [RangeIndex(start=0, stop=9, step=1),
#  Index(['First_Name', 'Last_Name', 'Age', 'Place', 'Married'], dtype='object')]

# %%
people_DataFrame
# Out:
#    First_Name Last_Name  Age        Place Married
# 0    Prasanna     Sahoo   30     Erlangen     Yes
# 1     Mamauni       NaN   30    Bangalore     Yes
# 2  nityananda     Sahoo   65  Bhubaneswar     Yes
# 3        Gugu       NaN   10        Nalco      No
# 4     Shradha     Sahoo   12  Bhubaneswar      No
# 5      Gopala     Sahoo   25      Sarikhi      No
# 6   Divynashu   Samanta   12     Hyderbad      No
# 7        Sibu     Sahoo    2      Kolkata      No
# 8        Debu     Sahoo    2        Nalco      No

# %%
people_DataFrame.set_index('First_Name', drop=False, append=False, inplace=False) 
# Above is to make any column as index, 
# Inplace=False dont change the original dataframe,...
# Drop=False dont change the original column also...
# append=False, removes the original index...
# Out:
#             First_Name Last_Name  Age        Place Married
# First_Name
# Prasanna      Prasanna     Sahoo   30     Erlangen     Yes
# Mamauni        Mamauni       NaN   30    Bangalore     Yes
# nityananda  nityananda     Sahoo   65  Bhubaneswar     Yes
# Gugu              Gugu       NaN   10        Nalco      No
# Shradha        Shradha     Sahoo   12  Bhubaneswar      No
# Gopala          Gopala     Sahoo   25      Sarikhi      No
# Divynashu    Divynashu   Samanta   12     Hyderbad      No
# Sibu              Sibu     Sahoo    2      Kolkata      No
# Debu              Debu     Sahoo    2        Nalco      No

# %%
people_DataFrame.set_index('First_Name', drop=True, append=False, inplace=True)

# %%
people_DataFrame
# Out:
#            Last_Name  Age        Place Married
# First_Name
# Prasanna       Sahoo   30     Erlangen     Yes
# Mamauni          NaN   30    Bangalore     Yes
# nityananda     Sahoo   65  Bhubaneswar     Yes
# Gugu             NaN   10        Nalco      No
# Shradha        Sahoo   12  Bhubaneswar      No
# Gopala         Sahoo   25      Sarikhi      No
# Divynashu    Samanta   12     Hyderbad      No
# Sibu           Sahoo    2      Kolkata      No
# Debu           Sahoo    2        Nalco      No

# %%
people_DataFrame.reset_index (inplace =True)

# %%
people_DataFrame.rename()
# Out:
#    First_Name      Last_Name  Age           Place Married  \
# 0    Prasanna          Sahoo   30        erlangen     Yes
# 1         Pjm            NaN   30       bangalore     Yes
# 2  nityananda          Sahoo   65     bhubaneswar     Yes
# 3      Ayesha  Priyadarshani    8  nalco_township      No
# 4     Shradha          Sahoo   12     bhubaneswar      No
# 5      Gopala          Sahoo   25         sarikhi      No
# 6   Divynashu        Samanta   12        hyderbad      No
# 7        Sibu          Sahoo    2         kolkata      No
# 8        Debu          Sahoo    2           nalco      No
#
#               Full_Name
# 0        Prasanna_Sahoo
# 1               Pjm_NaN
# 2      nityananda_Sahoo
# 3  Ayesha_Priyadarshani
# 4         Shradha_Sahoo
# 5          Gopala_Sahoo
# 6     Divynashu_Samanta
# 7            Sibu_Sahoo
# 8            Debu_Sahoo

# %%
people_DataFrame.sort_index(ascending=True)
# Out:
#    First_Name Last_Name  Age        Place Married
# 0    Prasanna     Sahoo   30     Erlangen     Yes
# 1     Mamauni       NaN   30    Bangalore     Yes
# 2  nityananda     Sahoo   65  Bhubaneswar     Yes
# 3        Gugu       NaN   10        Nalco      No
# 4     Shradha     Sahoo   12  Bhubaneswar      No
# 5      Gopala     Sahoo   25      Sarikhi      No
# 6   Divynashu   Samanta   12     Hyderbad      No
# 7        Sibu     Sahoo    2      Kolkata      No
# 8        Debu     Sahoo    2        Nalco      No

# %% [markdown]
# ##  Filetering in Pandas

# %%
filt = (people_DataFrame['Last_Name']=='Sahoo') & (people_DataFrame['Age']> 25 )

# %%
people_DataFrame[filt]   # filter directly from dataframe
# Out:
#    First_Name Last_Name  Age        Place Married
# 0    Prasanna     Sahoo   30     Erlangen     Yes
# 2  nityananda     Sahoo   65  Bhubaneswar     Yes

# %%
people_DataFrame
# Out:
#    First_Name Last_Name  Age        Place Married
# 0    Prasanna     Sahoo   30     Erlangen     Yes
# 1     Mamauni       NaN   30    Bangalore     Yes
# 2  nityananda     Sahoo   65  Bhubaneswar     Yes
# 3        Gugu       NaN   10        Nalco      No
# 4     Shradha     Sahoo   12  Bhubaneswar      No
# 5      Gopala     Sahoo   25      Sarikhi      No
# 6   Divynashu   Samanta   12     Hyderbad      No
# 7        Sibu     Sahoo    2      Kolkata      No
# 8        Debu     Sahoo    2        Nalco      No

# %%
people_DataFrame.loc[filt]    # Using Loc if you filter can use for other purpose
# Out:
#    First_Name Last_Name  Age        Place Married
# 0    Prasanna     Sahoo   30     Erlangen     Yes
# 2  nityananda     Sahoo   65  Bhubaneswar     Yes

# %%
people_DataFrame.loc[filt, 'Age']    # Using Loc
# Out:
# 0    30
# 2    65
# Name: Age, dtype: int64

# %%
people_DataFrame.loc[~filt, 'Age']    # Using negation of filter
# Out:
# 1    30
# 3    10
# 4    12
# 5    25
# 6    12
# 7     2
# 8     2
# Name: Age, dtype: int64

# %%
city=['Erlangen','Nalco','Sarikhi']
filt= people_DataFrame['Place'].isin(city)    # Using isin method

# %%
people_DataFrame.loc[filt]
# Out:
#   First_Name Last_Name  Age     Place Married
# 0   Prasanna     Sahoo   30  Erlangen     Yes
# 3       Gugu       NaN   10     Nalco      No
# 5     Gopala     Sahoo   25   Sarikhi      No
# 8       Debu     Sahoo    2     Nalco      No

# %%
people_DataFrame
# Out:
#    First_Name Last_Name  Age        Place Married
# 0    Prasanna     Sahoo   30     Erlangen     Yes
# 1     Mamauni       NaN   30    Bangalore     Yes
# 2  nityananda     Sahoo   65  Bhubaneswar     Yes
# 3        Gugu       NaN   10        Nalco      No
# 4     Shradha     Sahoo   12  Bhubaneswar      No
# 5      Gopala     Sahoo   25      Sarikhi      No
# 6   Divynashu   Samanta   12     Hyderbad      No
# 7        Sibu     Sahoo    2      Kolkata      No
# 8        Debu     Sahoo    2        Nalco      No

# %%
city=['Erlangen','Nalco','Sarikhi']
filt= people_DataFrame['Place'].str.contains('Sarikhi', regex = True)   # using str.contains
filt
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6    False
# 7    False
# 8    False
# Name: Place, dtype: bool

# %%
people_DataFrame.loc[filt]
# Out:
#   First_Name Last_Name  Age    Place Married
# 5     Gopala     Sahoo   25  Sarikhi      No

# %% [markdown]
# ## Updating rows and columns in DataFrame

# %%
people_DataFrame.columns
# Out:
# Index(['First_Name', 'Last_Name', 'Age', 'Place', 'Married'], dtype='object')

# %%
# people_DataFrame.columns = [x.lower() for x in people_DataFrame.columns]
people_DataFrame
# Out:
#    First_Name Last_Name  Age        Place Married
# 0    Prasanna     Sahoo   30     Erlangen     Yes
# 1     Mamauni       NaN   30    Bangalore     Yes
# 2  nityananda     Sahoo   65  Bhubaneswar     Yes
# 3        Gugu       NaN   10        Nalco      No
# 4     Shradha     Sahoo   12  Bhubaneswar      No
# 5      Gopala     Sahoo   25      Sarikhi      No
# 6   Divynashu   Samanta   12     Hyderbad      No
# 7        Sibu     Sahoo    2      Kolkata      No
# 8        Debu     Sahoo    2        Nalco      No

# %%
# people_DataFrame.columns = [people_DataFrame.columns.str.replace('_',':')]
people_DataFrame
# Out:
#    First_Name Last_Name  Age        Place Married
# 0    Prasanna     Sahoo   30     Erlangen     Yes
# 1     Mamauni       NaN   30    Bangalore     Yes
# 2  nityananda     Sahoo   65  Bhubaneswar     Yes
# 3        Gugu       NaN   10        Nalco      No
# 4     Shradha     Sahoo   12  Bhubaneswar      No
# 5      Gopala     Sahoo   25      Sarikhi      No
# 6   Divynashu   Samanta   12     Hyderbad      No
# 7        Sibu     Sahoo    2      Kolkata      No
# 8        Debu     Sahoo    2        Nalco      No

# %%
# Reanme column using dictionary
people_DataFrame.rename (columns = {'First_Name' : 'first_name','Last_Name' : 'last_name'})
# Out:
#    first_name last_name  Age        Place Married
# 0    Prasanna     Sahoo   30     Erlangen     Yes
# 1     Mamauni       NaN   30    Bangalore     Yes
# 2  nityananda     Sahoo   65  Bhubaneswar     Yes
# 3        Gugu       NaN   10        Nalco      No
# 4     Shradha     Sahoo   12  Bhubaneswar      No
# 5      Gopala     Sahoo   25      Sarikhi      No
# 6   Divynashu   Samanta   12     Hyderbad      No
# 7        Sibu     Sahoo    2      Kolkata      No
# 8        Debu     Sahoo    2        Nalco      No

# %%
# people_DataFrame.columns = ['A','B','C','D','E']
people_DataFrame
# Out:
#    First_Name Last_Name  Age        Place Married
# 0    Prasanna     Sahoo   30     Erlangen     Yes
# 1     Mamauni       NaN   30    Bangalore     Yes
# 2  nityananda     Sahoo   65  Bhubaneswar     Yes
# 3        Gugu       NaN   10        Nalco      No
# 4     Shradha     Sahoo   12  Bhubaneswar      No
# 5      Gopala     Sahoo   25      Sarikhi      No
# 6   Divynashu   Samanta   12     Hyderbad      No
# 7        Sibu     Sahoo    2      Kolkata      No
# 8        Debu     Sahoo    2        Nalco      No

# %%
# Changing the ROW using a total list of all columns, but here the list should have same length
people_DataFrame.loc[3] = ['Ayesha', 'Priyadarshani', 9,'Nalco Township', 'No' ]
people_DataFrame
# Out:
#    First_Name      Last_Name  Age           Place Married
# 0    Prasanna          Sahoo   30        Erlangen     Yes
# 1     Mamauni            NaN   30       Bangalore     Yes
# 2  nityananda          Sahoo   65     Bhubaneswar     Yes
# 3      Ayesha  Priyadarshani    9  Nalco Township      No
# 4     Shradha          Sahoo   12     Bhubaneswar      No
# 5      Gopala          Sahoo   25         Sarikhi      No
# 6   Divynashu        Samanta   12        Hyderbad      No
# 7        Sibu          Sahoo    2         Kolkata      No
# 8        Debu          Sahoo    2           Nalco      No

# %%
people_DataFrame.loc[3, ['Place','Age']] = ['Nalco_Township',8]
people_DataFrame
# Out:
#    First_Name      Last_Name  Age           Place Married
# 0    Prasanna          Sahoo   30        Erlangen     Yes
# 1     Mamauni            NaN   30       Bangalore     Yes
# 2  nityananda          Sahoo   65     Bhubaneswar     Yes
# 3      Ayesha  Priyadarshani    8  Nalco_Township      No
# 4     Shradha          Sahoo   12     Bhubaneswar      No
# 5      Gopala          Sahoo   25         Sarikhi      No
# 6   Divynashu        Samanta   12        Hyderbad      No
# 7        Sibu          Sahoo    2         Kolkata      No
# 8        Debu          Sahoo    2           Nalco      No

# %%
people_DataFrame['Place']= people_DataFrame['Place'].str.lower()
people_DataFrame
# Out:
#    First_Name      Last_Name  Age           Place Married
# 0    Prasanna          Sahoo   30        erlangen     Yes
# 1     Mamauni            NaN   30       bangalore     Yes
# 2  nityananda          Sahoo   65     bhubaneswar     Yes
# 3      Ayesha  Priyadarshani    8  nalco_township      No
# 4     Shradha          Sahoo   12     bhubaneswar      No
# 5      Gopala          Sahoo   25         sarikhi      No
# 6   Divynashu        Samanta   12        hyderbad      No
# 7        Sibu          Sahoo    2         kolkata      No
# 8        Debu          Sahoo    2           nalco      No

# %%
people_DataFrame['Place'].apply(len)  #Apply is possible in Series case only.
# Out:
# 0     8
# 1     9
# 2    11
# 3    14
# 4    11
# 5     7
# 6     8
# 7     7
# 8     5
# Name: Place, dtype: int64

# %%
people_DataFrame.apply(len, axis = 'columns')
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# 4    5
# 5    5
# 6    5
# 7    5
# 8    5
# dtype: int64

# %%
people_DataFrame.apply(len, axis = 'rows')
# Out:
# First_Name    9
# Last_Name     9
# Age           9
# Place         9
# Married       9
# dtype: int64

# %%
people_DataFrame.apply(len)
# Out:
# First_Name    9
# Last_Name     9
# Age           9
# Place         9
# Married       9
# dtype: int64

# %%
def update_place(x):
    return x.upper()

# %%
people_DataFrame['Place'] = people_DataFrame['Place'].apply(update_place)
people_DataFrame
# Out:
#    First_Name      Last_Name  Age           Place Married
# 0    Prasanna          Sahoo   30        ERLANGEN     Yes
# 1     Mamauni            NaN   30       BANGALORE     Yes
# 2  nityananda          Sahoo   65     BHUBANESWAR     Yes
# 3      Ayesha  Priyadarshani    8  NALCO_TOWNSHIP      No
# 4     Shradha          Sahoo   12     BHUBANESWAR      No
# 5      Gopala          Sahoo   25         SARIKHI      No
# 6   Divynashu        Samanta   12        HYDERBAD      No
# 7        Sibu          Sahoo    2         KOLKATA      No
# 8        Debu          Sahoo    2           NALCO      No

# %%
people_DataFrame['Place'] = people_DataFrame['Place'].apply(lambda x: x.lower())
people_DataFrame
# Out:
#    First_Name      Last_Name  Age           Place Married
# 0    Prasanna          Sahoo   30        erlangen     Yes
# 1     Mamauni            NaN   30       bangalore     Yes
# 2  nityananda          Sahoo   65     bhubaneswar     Yes
# 3      Ayesha  Priyadarshani    8  nalco_township      No
# 4     Shradha          Sahoo   12     bhubaneswar      No
# 5      Gopala          Sahoo   25         sarikhi      No
# 6   Divynashu        Samanta   12        hyderbad      No
# 7        Sibu          Sahoo    2         kolkata      No
# 8        Debu          Sahoo    2           nalco      No

# %%
people_DataFrame.apply(pd.Series.min)  # Apply method is applicable to series of the DataFrame
# Out:
# First_Name       Ayesha
# Last_Name           NaN
# Age                   2
# Place         bangalore
# Married              No
# dtype: object

# %%
people_DataFrame.apply(lambda x: x.min())
# Out:
# First_Name       Ayesha
# Last_Name           NaN
# Age                   2
# Place         bangalore
# Married              No
# dtype: object

# %%
# people_DataFrame.applymap(str.lower) # apply map is applicable to each element of Dataframe. & Only posible ifeach element is a string.

# %%
people_DataFrame['First_Name'].map({'Prasanna':'Pj'}) # replaces thar sertain column and others will be NaN as return
# Out:
# 0     Pj
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# Name: First_Name, dtype: object

# %%
people_DataFrame['First_Name'] = people_DataFrame['First_Name'].replace('Mamauni','Pjm')
people_DataFrame
# Out:
#    First_Name      Last_Name  Age           Place Married
# 0    Prasanna          Sahoo   30        erlangen     Yes
# 1         Pjm            NaN   30       bangalore     Yes
# 2  nityananda          Sahoo   65     bhubaneswar     Yes
# 3      Ayesha  Priyadarshani    8  nalco_township      No
# 4     Shradha          Sahoo   12     bhubaneswar      No
# 5      Gopala          Sahoo   25         sarikhi      No
# 6   Divynashu        Samanta   12        hyderbad      No
# 7        Sibu          Sahoo    2         kolkata      No
# 8        Debu          Sahoo    2           nalco      No

# %% [markdown]
# ## Add/Remove Rows and Columns
#
#
# .  .str.contains

# %%
people_DataFrame['First_Name']+ '_' + people_DataFrame['Last_Name']
# Out:
# 0          Prasanna_Sahoo
# 1                 Pjm_NaN
# 2        nityananda_Sahoo
# 3    Ayesha_Priyadarshani
# 4           Shradha_Sahoo
# 5            Gopala_Sahoo
# 6       Divynashu_Samanta
# 7              Sibu_Sahoo
# 8              Debu_Sahoo
# dtype: object

# %%
people_DataFrame['Full_Name'] = people_DataFrame['First_Name']+ '_' + people_DataFrame['Last_Name']
people_DataFrame
# Out:
#    First_Name      Last_Name  Age           Place Married  \
# 0    Prasanna          Sahoo   30        erlangen     Yes
# 1         Pjm            NaN   30       bangalore     Yes
# 2  nityananda          Sahoo   65     bhubaneswar     Yes
# 3      Ayesha  Priyadarshani    8  nalco_township      No
# 4     Shradha          Sahoo   12     bhubaneswar      No
# 5      Gopala          Sahoo   25         sarikhi      No
# 6   Divynashu        Samanta   12        hyderbad      No
# 7        Sibu          Sahoo    2         kolkata      No
# 8        Debu          Sahoo    2           nalco      No
#
#               Full_Name
# 0        Prasanna_Sahoo
# 1               Pjm_NaN
# 2      nityananda_Sahoo
# 3  Ayesha_Priyadarshani
# 4         Shradha_Sahoo
# 5          Gopala_Sahoo
# 6     Divynashu_Samanta
# 7            Sibu_Sahoo
# 8            Debu_Sahoo

# %%
people_DataFrame.drop(columns= ['First_Name','Last_Name'], inplace=False)
# Out:
#    Age           Place Married             Full_Name
# 0   30        erlangen     Yes        Prasanna_Sahoo
# 1   30       bangalore     Yes               Pjm_NaN
# 2   65     bhubaneswar     Yes      nityananda_Sahoo
# 3    8  nalco_township      No  Ayesha_Priyadarshani
# 4   12     bhubaneswar      No         Shradha_Sahoo
# 5   25         sarikhi      No          Gopala_Sahoo
# 6   12        hyderbad      No     Divynashu_Samanta
# 7    2         kolkata      No            Sibu_Sahoo
# 8    2           nalco      No            Debu_Sahoo

# %%
people_DataFrame['Full_Name'].str.split('_')
# Out:
# 0          [Prasanna, Sahoo]
# 1                 [Pjm, NaN]
# 2        [nityananda, Sahoo]
# 3    [Ayesha, Priyadarshani]
# 4           [Shradha, Sahoo]
# 5            [Gopala, Sahoo]
# 6       [Divynashu, Samanta]
# 7              [Sibu, Sahoo]
# 8              [Debu, Sahoo]
# Name: Full_Name, dtype: object

# %%
people_DataFrame['Full_Name'].str.split('_', expand=True)
# Out:
#             0              1
# 0    Prasanna          Sahoo
# 1         Pjm            NaN
# 2  nityananda          Sahoo
# 3      Ayesha  Priyadarshani
# 4     Shradha          Sahoo
# 5      Gopala          Sahoo
# 6   Divynashu        Samanta
# 7        Sibu          Sahoo
# 8        Debu          Sahoo

# %%
people_DataFrame[['First_Name','Last_Name']] = people_DataFrame['Full_Name'].str.split('_', expand= True)
people_DataFrame
# Out:
#    First_Name      Last_Name  Age           Place Married  \
# 0    Prasanna          Sahoo   30        erlangen     Yes
# 1         Pjm            NaN   30       bangalore     Yes
# 2  nityananda          Sahoo   65     bhubaneswar     Yes
# 3      Ayesha  Priyadarshani    8  nalco_township      No
# 4     Shradha          Sahoo   12     bhubaneswar      No
# 5      Gopala          Sahoo   25         sarikhi      No
# 6   Divynashu        Samanta   12        hyderbad      No
# 7        Sibu          Sahoo    2         kolkata      No
# 8        Debu          Sahoo    2           nalco      No
#
#               Full_Name
# 0        Prasanna_Sahoo
# 1               Pjm_NaN
# 2      nityananda_Sahoo
# 3  Ayesha_Priyadarshani
# 4         Shradha_Sahoo
# 5          Gopala_Sahoo
# 6     Divynashu_Samanta
# 7            Sibu_Sahoo
# 8            Debu_Sahoo

# %%
people_DataFrame.drop(index=4)  #Drop row number 4
# Out:
#    First_Name      Last_Name  Age           Place Married  \
# 0    Prasanna          Sahoo   30        erlangen     Yes
# 1         Pjm            NaN   30       bangalore     Yes
# 2  nityananda          Sahoo   65     bhubaneswar     Yes
# 3      Ayesha  Priyadarshani    8  nalco_township      No
# 5      Gopala          Sahoo   25         sarikhi      No
# 6   Divynashu        Samanta   12        hyderbad      No
# 7        Sibu          Sahoo    2         kolkata      No
# 8        Debu          Sahoo    2           nalco      No
#
#               Full_Name
# 0        Prasanna_Sahoo
# 1               Pjm_NaN
# 2      nityananda_Sahoo
# 3  Ayesha_Priyadarshani
# 5          Gopala_Sahoo
# 6     Divynashu_Samanta
# 7            Sibu_Sahoo
# 8            Debu_Sahoo

# %%
filt= people_DataFrame['Last_Name']=='NaN'
# index_num1= people_DataFrame[filt].index
people_DataFrame.drop(index=people_DataFrame[filt].index)
# Out:
#    First_Name      Last_Name  Age           Place Married  \
# 0    Prasanna          Sahoo   30        erlangen     Yes
# 2  nityananda          Sahoo   65     bhubaneswar     Yes
# 3      Ayesha  Priyadarshani    8  nalco_township      No
# 4     Shradha          Sahoo   12     bhubaneswar      No
# 5      Gopala          Sahoo   25         sarikhi      No
# 6   Divynashu        Samanta   12        hyderbad      No
# 7        Sibu          Sahoo    2         kolkata      No
# 8        Debu          Sahoo    2           nalco      No
#
#               Full_Name
# 0        Prasanna_Sahoo
# 2      nityananda_Sahoo
# 3  Ayesha_Priyadarshani
# 4         Shradha_Sahoo
# 5          Gopala_Sahoo
# 6     Divynashu_Samanta
# 7            Sibu_Sahoo
# 8            Debu_Sahoo

# %%
people_DataFrame.append({'Last_Name':'Panda'}, ignore_index=True)
# Out:
#    First_Name      Last_Name   Age           Place Married  \
# 0    Prasanna          Sahoo  30.0        erlangen     Yes
# 1         Pjm            NaN  30.0       bangalore     Yes
# 2  nityananda          Sahoo  65.0     bhubaneswar     Yes
# 3      Ayesha  Priyadarshani   8.0  nalco_township      No
# 4     Shradha          Sahoo  12.0     bhubaneswar      No
# 5      Gopala          Sahoo  25.0         sarikhi      No
# 6   Divynashu        Samanta  12.0        hyderbad      No
# 7        Sibu          Sahoo   2.0         kolkata      No
# 8        Debu          Sahoo   2.0           nalco      No
# 9         NaN          Panda   NaN             NaN     NaN
#
#               Full_Name
# 0        Prasanna_Sahoo
# 1               Pjm_NaN
# 2      nityananda_Sahoo
# 3  Ayesha_Priyadarshani
# 4         Shradha_Sahoo
# 5          Gopala_Sahoo
# 6     Divynashu_Samanta
# 7            Sibu_Sahoo
# 8            Debu_Sahoo
# 9                   NaN

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],'B': ['B0', 'B1', 'B2', 'B3'],'C': ['C0', 'C1', 'C2', 'C3'],'D': ['D0', 'D1', 'D2', 'D3']},index=[0, 1, 2, 3])
s1 = pd.Series(['X0', 'X1', 'X2', 'X3'], name='X')
s11 = pd.Series(['X0', 'X1', 'X2', 'X3'])
s11_df=pd.DataFrame([s11])

s2 = pd.Series(['X0', 'X1', 'X2', 'X3'], index=['A', 'B', 'C', 'D'],name='X')
s3 = pd.Series(['X0', 'X1', 'X2', 'X3'], index=[1, 2, 3, 4],name='X')

s2_df=pd.DataFrame([s2])
s3_df=pd.DataFrame([s3])
print (df1)
print (s2)
result = pd.concat([df1, s1], axis=1)  #axis=1, means rows  #axis{0 or ‘index’, 1 or ‘columns’}, default 0
# result = pd.concat([df1, s1], axis=0)
result1 = df1.append(s2,ignore_index=True, sort=True)    # correct result as index is correct
result3 = pd.concat([s2_df,df1],ignore_index=True)
result31 = pd.concat([df1, s3], axis='columns',ignore_index=True)
result4 = df1.append(s1,ignore_index=True, sort=True)

#for row use append and columns use concat

print (type(s2))
print (s3)
df1
print (f'result:- \n {result}')
print(f'result1:- \n {result1}')
print (f'result3:- \n {result3}')
print (f'result31:- \n {result31}')
print (f'result4:- \n {result4}')
s1_df
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
# A    X0
# B    X1
# C    X2
# D    X3
# Name: X, dtype: object
# <class 'pandas.core.series.Series'>
# 1    X0
# 2    X1
# 3    X2
# 4    X3
# Name: X, dtype: object
# result:-
#      A   B   C   D   X
# 0  A0  B0  C0  D0  X0
# 1  A1  B1  C1  D1  X1
# 2  A2  B2  C2  D2  X2
# 3  A3  B3  C3  D3  X3
# result1:-
#      A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
# 4  X0  X1  X2  X3
# result3:-
#      A   B   C   D
# 0  X0  X1  X2  X3
# 1  A0  B0  C0  D0
# 2  A1  B1  C1  D1
# 3  A2  B2  C2  D2
# 4  A3  B3  C3  D3
# result31:-
#       0    1    2    3    4
# 0   A0   B0   C0   D0  NaN
# 1   A1   B1   C1   D1   X0
# 2   A2   B2   C2   D2   X1
# 3   A3   B3   C3   D3   X2
# 4  NaN  NaN  NaN  NaN   X3
# result4:-
#       A    B    C    D    0    1    2    3
# 0   A0   B0   C0   D0  NaN  NaN  NaN  NaN
# 1   A1   B1   C1   D1  NaN  NaN  NaN  NaN
# ...

# %%
a_row = pd.Series([1, 2])
df = pd.DataFrame([[3, 4], [5, 6]])

row_df = pd.DataFrame([a_row])
df = pd.concat([row_df, df], ignore_index=True)
df
# Out:
#    0  1
# 0  1  2
# 1  3  4
# 2  5  6

# %%
a_row = pd.Series(['A', 'B'])
df = pd.DataFrame([{'a':['C', 'D'],'b': ['F', 'D']}])

row_df = pd.DataFrame([a_row])
df = pd.concat([row_df, df], ignore_index=True)
df
# Out:
#      0    1       a       b
# 0    A    B     NaN     NaN
# 1  NaN  NaN  [C, D]  [F, D]

# %% [markdown]
# 1.https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html

# %% [markdown]
# ## Sorting of Datas

# %%
people_DataFrame.sort_values(by='Age', ascending=False)  # Sort by age column, with descending oder
# Out:
#    First_Name      Last_Name  Age           Place Married  \
# 2  nityananda          Sahoo   65     bhubaneswar     Yes
# 0    Prasanna          Sahoo   30        erlangen     Yes
# 1         Pjm            NaN   30       bangalore     Yes
# 5      Gopala          Sahoo   25         sarikhi      No
# 4     Shradha          Sahoo   12     bhubaneswar      No
# 6   Divynashu        Samanta   12        hyderbad      No
# 3      Ayesha  Priyadarshani    8  nalco_township      No
# 7        Sibu          Sahoo    2         kolkata      No
# 8        Debu          Sahoo    2           nalco      No
#
#               Full_Name
# 2      nityananda_Sahoo
# 0        Prasanna_Sahoo
# 1               Pjm_NaN
# 5          Gopala_Sahoo
# 4         Shradha_Sahoo
# 6     Divynashu_Samanta
# 3  Ayesha_Priyadarshani
# 7            Sibu_Sahoo
# 8            Debu_Sahoo

# %%
people_DataFrame.sort_values(by=['Age', 'First_Name'], ascending=False) # sort by age , then if sameage sort by First_Name, but first name cant be descending
# Out:
#    First_Name      Last_Name  Age           Place Married  \
# 2  nityananda          Sahoo   65     bhubaneswar     Yes
# 0    Prasanna          Sahoo   30        erlangen     Yes
# 1         Pjm            NaN   30       bangalore     Yes
# 5      Gopala          Sahoo   25         sarikhi      No
# 4     Shradha          Sahoo   12     bhubaneswar      No
# 6   Divynashu        Samanta   12        hyderbad      No
# 3      Ayesha  Priyadarshani    8  nalco_township      No
# 7        Sibu          Sahoo    2         kolkata      No
# 8        Debu          Sahoo    2           nalco      No
#
#               Full_Name
# 2      nityananda_Sahoo
# 0        Prasanna_Sahoo
# 1               Pjm_NaN
# 5          Gopala_Sahoo
# 4         Shradha_Sahoo
# 6     Divynashu_Samanta
# 3  Ayesha_Priyadarshani
# 7            Sibu_Sahoo
# 8            Debu_Sahoo

# %%
people_DataFrame.sort_values(by=['Age','First_Name'], ascending=[False, False], inplace= False) # each column/series can be changed
# Out:
#    First_Name      Last_Name  Age           Place Married  \
# 2  nityananda          Sahoo   65     bhubaneswar     Yes
# 0    Prasanna          Sahoo   30        erlangen     Yes
# 1         Pjm            NaN   30       bangalore     Yes
# 5      Gopala          Sahoo   25         sarikhi      No
# 4     Shradha          Sahoo   12     bhubaneswar      No
# 6   Divynashu        Samanta   12        hyderbad      No
# 3      Ayesha  Priyadarshani    8  nalco_township      No
# 7        Sibu          Sahoo    2         kolkata      No
# 8        Debu          Sahoo    2           nalco      No
#
#               Full_Name
# 2      nityananda_Sahoo
# 0        Prasanna_Sahoo
# 1               Pjm_NaN
# 5          Gopala_Sahoo
# 4         Shradha_Sahoo
# 6     Divynashu_Samanta
# 3  Ayesha_Priyadarshani
# 7            Sibu_Sahoo
# 8            Debu_Sahoo

# %%
# Sort index
people_DataFrame.sort_index()
# Out:
#    First_Name      Last_Name  Age           Place Married  \
# 0    Prasanna          Sahoo   30        erlangen     Yes
# 1         Pjm            NaN   30       bangalore     Yes
# 2  nityananda          Sahoo   65     bhubaneswar     Yes
# 3      Ayesha  Priyadarshani    8  nalco_township      No
# 4     Shradha          Sahoo   12     bhubaneswar      No
# 5      Gopala          Sahoo   25         sarikhi      No
# 6   Divynashu        Samanta   12        hyderbad      No
# 7        Sibu          Sahoo    2         kolkata      No
# 8        Debu          Sahoo    2           nalco      No
#
#               Full_Name
# 0        Prasanna_Sahoo
# 1               Pjm_NaN
# 2      nityananda_Sahoo
# 3  Ayesha_Priyadarshani
# 4         Shradha_Sahoo
# 5          Gopala_Sahoo
# 6     Divynashu_Samanta
# 7            Sibu_Sahoo
# 8            Debu_Sahoo

# %%
#Sort only a dataframe series
people_DataFrame['First_Name'].sort_values()
# Out:
# 3        Ayesha
# 8          Debu
# 6     Divynashu
# 5        Gopala
# 1           Pjm
# 0      Prasanna
# 4       Shradha
# 7          Sibu
# 2    nityananda
# Name: First_Name, dtype: object

# %%
people_DataFrame['Age'].nlargest(5)   # gett the 5 largest age from age column
# Out:
# 2    65
# 0    30
# 1    30
# 5    25
# 4    12
# Name: Age, dtype: int64

# %%
people_DataFrame.nlargest(5,'Age') # this returns the df with 5 largest age
# Out:
#    First_Name Last_Name  Age        Place Married         Full_Name
# 2  nityananda     Sahoo   65  bhubaneswar     Yes  nityananda_Sahoo
# 0    Prasanna     Sahoo   30     erlangen     Yes    Prasanna_Sahoo
# 1         Pjm       NaN   30    bangalore     Yes           Pjm_NaN
# 5      Gopala     Sahoo   25      sarikhi      No      Gopala_Sahoo
# 4     Shradha     Sahoo   12  bhubaneswar      No     Shradha_Sahoo

# %%
people_DataFrame.nlargest(5,'Age').sort_index() # this returns the df with 5 largest age
# Out:
#    First_Name Last_Name  Age        Place Married         Full_Name
# 0    Prasanna     Sahoo   30     erlangen     Yes    Prasanna_Sahoo
# 1         Pjm       NaN   30    bangalore     Yes           Pjm_NaN
# 2  nityananda     Sahoo   65  bhubaneswar     Yes  nityananda_Sahoo
# 4     Shradha     Sahoo   12  bhubaneswar      No     Shradha_Sahoo
# 5      Gopala     Sahoo   25      sarikhi      No      Gopala_Sahoo

# %%
people_DataFrame.nsmallest(5,'Age').sort_index() # this returns the df with 5 smallest age
# Out:
#   First_Name      Last_Name  Age           Place Married             Full_Name
# 3     Ayesha  Priyadarshani    8  nalco_township      No  Ayesha_Priyadarshani
# 4    Shradha          Sahoo   12     bhubaneswar      No         Shradha_Sahoo
# 6  Divynashu        Samanta   12        hyderbad      No     Divynashu_Samanta
# 7       Sibu          Sahoo    2         kolkata      No            Sibu_Sahoo
# 8       Debu          Sahoo    2           nalco      No            Debu_Sahoo

# %% [markdown]
# ## Grouping & Aggregate
#
#     1. df.mean(axis=1) # Axis=1 creates mean along the Rows, Axis =0 creates mean along Columns

# %%
people_DataFrame.describe()  # describe returns the details for numerical columns/series
# Out:
#              Age
# count   9.000000
# mean   20.666667
# std    19.893466
# min     2.000000
# 25%     8.000000
# 50%    12.000000
# 75%    30.000000
# max    65.000000

# %%
people_DataFrame['Age'].mean()
# Out:
# 20.666666666666668

# %%
people_DataFrame['Place'].value_counts()
# Out:
# bhubaneswar       2
# nalco             1
# sarikhi           1
# erlangen          1
# kolkata           1
# hyderbad          1
# bangalore         1
# nalco_township    1
# Name: Place, dtype: int64

# %%
people_DataFrame['Place'].value_counts(normalize=True) # conveted to %
# Out:
# bhubaneswar       0.222222
# nalco             0.111111
# sarikhi           0.111111
# erlangen          0.111111
# kolkata           0.111111
# hyderbad          0.111111
# bangalore         0.111111
# nalco_township    0.111111
# Name: Place, dtype: float64

# %%
pwd
# Out:
# 'C:\\Users\\psahoo\\Documents\\PJ\\python\\Python_Ref_Note\\Pandas'

# %%
na_vals=['NA','Missing']
df= pd.read_csv('survey_results_public.csv',na_values= na_vals)
df[['Respondent','Country']]
# Out:
#        Respondent                 Country
# 0               1          United Kingdom
# 1               2  Bosnia and Herzegovina
# 2               3                Thailand
# 3               4           United States
# 4               5                 Ukraine
# 5               6                  Canada
# 6               7                 Ukraine
# 7               8                   India
# 8               9             New Zealand
# 9              10                   India
# 10             11     Antigua and Barbuda
# 11             12                  Canada
# 12             13           United States
# 13             14                 Germany
# 14             15                   India
# 15             16          United Kingdom
# 16             17               Australia
# 17             18      Russian Federation
# 18             19                  Brazil
# 19             20               Lithuania
# 20             21                  Canada
# ...

# %%
df.head()
df.axes
df.shape
# Out:
# (88883, 85)

# %%
df.columns.sort_values()
# Out:
# Index(['Age', 'Age1stCode', 'BetterLife', 'BlockchainIs', 'BlockchainOrg',
#        'CareerSat', 'CodeRev', 'CodeRevHrs', 'CompFreq', 'CompTotal',
#        'Containers', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'Dependents', 'DevEnviron', 'DevType', 'EdLevel', 'EduOther',
#        'Employment', 'EntTeams', 'Ethnicity', 'Extraversion', 'FizzBuzz',
#        'Gender', 'Hobbyist', 'ITperson', 'ImpSyn', 'JobFactors', 'JobSat',
#        'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'LastHireDate', 'LastInt', 'MainBranch', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'MiscTechDesireNextYear', 'MiscTechWorkedWith', 'OffOn',
#        'OpSys', 'OpenSource', 'OpenSourcer', 'OrgSize',
#        'PlatformDesireNextYear', 'PlatformWorkedWith', 'PurchaseHow',
#        'PurchaseWhat', 'Respondent', 'ResumeUpdate', 'SOAccount', 'SOComm',
# ...

# %%
country_group = df.groupby(['Country'])

print(type(country_group))
print(type(country_group['Country']))
print (type(country_group.get_group('India')))
# Out:
# <class 'pandas.core.groupby.generic.DataFrameGroupBy'>
# <class 'pandas.core.groupby.generic.SeriesGroupBy'>
# <class 'pandas.core.frame.DataFrame'>

# %%
country_group.get_group('India')
# Out:
#        Respondent                              MainBranch Hobbyist  \
# 7               8             I code primarily as a hobby      Yes
# 9              10          I am a developer by profession      Yes
# 14             15  I am a student who is learning to code      Yes
# 49             50          I am a developer by profession      Yes
# 64             65          I am a developer by profession      Yes
# 67             68          I am a developer by profession      Yes
# 74             75          I am a developer by profession      Yes
# 77             78          I am a developer by profession       No
# 82             83          I am a developer by profession      Yes
# 88             89  I am a student who is learning to code      Yes
# 89             90          I am a developer by profession      Yes
# 98             99  I am a student who is learning to code      Yes
# 103           104          I am a developer by profession      Yes
# ...

# %%
country_group.get_group('India')['Respondent']
# Out:
# 7            8
# 9           10
# 14          15
# 49          50
# 64          65
# 67          68
# 74          75
# 77          78
# 82          83
# 88          89
# 89          90
# 98          99
# 103        104
# 120        121
# 123        124
# 138        140
# 167        169
# 172        174
# 174        176
# 176        178
# 218        220
# 236        238
# 237        239
# 240        242
# 261        263
# 269        271
# 286        288
# 289        291
# 341        343
# 342        344
#          ...
# 88291    88843
# 88304    88856
# 88316    88869
# 88319    88872
# 88398    14444
# 88439    20000
# 88444    20567
# 88445    20892
# 88446    21826
# 88470    24606
# 88475    25114
# 88483    26419
# 88488    27229
# 88546    35010
# 88577    40151
# 88587    40898
# 88599    42599
# 88605    43809
# 88658    50685
# 88711    60133
# 88737    63972
# 88748    65988
# 88783    71874
# 88798    75103
# 88806    76822
# 88808    77339
# 88825    79795
# ...

# %%
country_group['SocialMedia'].value_counts(normalize=True).head(10)
# country_group['SocialMedia'].value_counts(normalize=True).loc['United States']
# Out:
# Country      SocialMedia
# Afghanistan  Facebook                    0.405405
#              YouTube                     0.243243
#              I don't use social media    0.162162
#              WhatsApp                    0.108108
#              Instagram                   0.027027
#              LinkedIn                    0.027027
#              Twitter                     0.027027
# Albania      WhatsApp                    0.214286
#              Facebook                    0.190476
#              Instagram                   0.154762
# Name: SocialMedia, dtype: float64

# %%
#country_group['Age'].median()
country_group['Age'].median().loc['India']
# Out:
# 25.0

# %%
# country_group['Age'].agg(['median','mean'])
country_group['Age'].agg(['median','mean']).loc['India'] #.mean()
# Out:
# median    25.000000
# mean      25.927439
# Name: India, dtype: float64

# %%
# country_group.get_group('India')['LanguageWorkedWith'].str.contains('Python')
print (country_group.get_group('India')['LanguageWorkedWith'].str.contains('Python').value_counts())
print (country_group.get_group('India')['LanguageWorkedWith'].str.contains('Python').sum())
# Out:
# False    5739
# True     3105
# Name: LanguageWorkedWith, dtype: int64
# 3105

# %%
# country_group['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python')).sum()
country_group['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum()).loc['India']
# country_group['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 3105

# %%
country_repondent= df['Country'].value_counts()
Contry_uses_python= country_group['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
new_df= pd.concat([country_repondent,Contry_uses_python], axis= 'columns',sort=True)
new_df['pecKnowPython'] = (new_df['Country']/new_df['LanguageWorkedWith'])*100
new_df
# Out:
#                                            Country  LanguageWorkedWith  \
# Afghanistan                                     44                   8
# Albania                                         86                  23
# Algeria                                        134                  40
# Andorra                                          7                   0
# Angola                                           5                   2
# Antigua and Barbuda                              9                   0
# Argentina                                      553                 191
# Armenia                                         86                  28
# Australia                                     1903                 790
# Austria                                        839                 338
# Azerbaijan                                      49                  17
# Bahamas                                          3                   2
# ...

# %% [markdown]
# ## Casting Data Types and Handling Missing Data
#
#     1. read_csv  na_values to be assigned for list of non available values.
#      na_vals=['NA','Missing']
#      df= pd.read_csv('survey_results_public.csv',na_values= na_vals)
#
#     2. df.dropna(axis='index', how='any', inplace=False)
#      how can be 'all' or 'any'
#
#     3. df.replace({'oldvalue':'newvalue')
#
#     4. df.fillna(0)
#        df.isna()
#        df.dtypes
#
#
#     5. df['columns'].mean()
#        df['columns'].median()

# %%
import numpy as np

# %%
people = {'First_Name': ['Prasanna', 'Mamauni', 'nityananda', 'Gugu','Shradha', np.nan, 'Divynashu','Sibu','Debu',np.nan],
          'Last_Name' : ['Sahoo', np.nan, 'Sahoo', 'NA', 'Sahoo', 'Sahoo','Samanta','Sahoo','Sahoo',np.nan],
          'Age': [30,30,65,10,12,25,12,2,2,np.nan],
          'Place' :['Erlangen','Bangalore','Bhubaneswar','Nalco','Missing','Sarikhi','Hyderbad','Kolkata','Nalco',np.nan],
          'Married' :['Yes','Yes','Yes','No',np.nan,'No',None,'Not available','No',np.nan]
          
          }

# %%
people_np = pd.DataFrame(people)
people_np
# Out:
#    First_Name Last_Name   Age        Place        Married
# 0    Prasanna     Sahoo  30.0     Erlangen            Yes
# 1     Mamauni       NaN  30.0    Bangalore            Yes
# 2  nityananda     Sahoo  65.0  Bhubaneswar            Yes
# 3        Gugu        NA  10.0        Nalco             No
# 4     Shradha     Sahoo  12.0      Missing            NaN
# 5         NaN     Sahoo  25.0      Sarikhi             No
# 6   Divynashu   Samanta  12.0     Hyderbad           None
# 7        Sibu     Sahoo   2.0      Kolkata  Not available
# 8        Debu     Sahoo   2.0        Nalco             No
# 9         NaN       NaN   NaN          NaN            NaN

# %%
#Drop nan is used to drop the row which is have nan value
people_np.dropna()
people_np.dropna(axis='index', how='any', inplace=False) #default setting for dropna

# How van be 
#1. All= if want to drop rows withh all values as NAN
#2.
# Out:
#    First_Name Last_Name   Age        Place        Married
# 0    Prasanna     Sahoo  30.0     Erlangen            Yes
# 2  nityananda     Sahoo  65.0  Bhubaneswar            Yes
# 3        Gugu        NA  10.0        Nalco             No
# 7        Sibu     Sahoo   2.0      Kolkata  Not available
# 8        Debu     Sahoo   2.0        Nalco             No

# %%
#people_np.dropna(axis='columns', how='any', inplace=False)

# %%
people_np
# Out:
#    First_Name Last_Name   Age        Place        Married
# 0    Prasanna     Sahoo  30.0     Erlangen            Yes
# 1     Mamauni       NaN  30.0    Bangalore            Yes
# 2  nityananda     Sahoo  65.0  Bhubaneswar            Yes
# 3        Gugu        NA  10.0        Nalco             No
# 4     Shradha     Sahoo  12.0      Missing            NaN
# 5         NaN     Sahoo  25.0      Sarikhi             No
# 6   Divynashu   Samanta  12.0     Hyderbad           None
# 7        Sibu     Sahoo   2.0      Kolkata  Not available
# 8        Debu     Sahoo   2.0        Nalco             No
# 9         NaN       NaN   NaN          NaN            NaN

# %%
people_np.dropna(axis='index', how='any',subset=['Last_Name'])

# Subset defines the specific column to be used to filter
# Out:
#    First_Name Last_Name   Age        Place        Married
# 0    Prasanna     Sahoo  30.0     Erlangen            Yes
# 2  nityananda     Sahoo  65.0  Bhubaneswar            Yes
# 3        Gugu        NA  10.0        Nalco             No
# 4     Shradha     Sahoo  12.0      Missing            NaN
# 5         NaN     Sahoo  25.0      Sarikhi             No
# 6   Divynashu   Samanta  12.0     Hyderbad           None
# 7        Sibu     Sahoo   2.0      Kolkata  Not available
# 8        Debu     Sahoo   2.0        Nalco             No

# %%
people_np.dropna(axis='index', how='any',subset=['First_Name', 'Last_Name'])

#Checks in both cloumns
# Out:
#    First_Name Last_Name   Age        Place        Married
# 0    Prasanna     Sahoo  30.0     Erlangen            Yes
# 2  nityananda     Sahoo  65.0  Bhubaneswar            Yes
# 3        Gugu        NA  10.0        Nalco             No
# 4     Shradha     Sahoo  12.0      Missing            NaN
# 6   Divynashu   Samanta  12.0     Hyderbad           None
# 7        Sibu     Sahoo   2.0      Kolkata  Not available
# 8        Debu     Sahoo   2.0        Nalco             No

# %%
people_np.replace({'NA':np.nan,'Missing':np.nan}, inplace=True) 
# replace all unwanted strigs to np.nan, will be use full later to replace

# %%
people_np.isna()
# Out:
#    First_Name  Last_Name    Age  Place  Married
# 0       False      False  False  False    False
# 1       False       True  False  False    False
# 2       False      False  False  False    False
# 3       False       True  False  False    False
# 4       False      False  False   True     True
# 5        True      False  False  False    False
# 6       False      False  False  False     True
# 7       False      False  False  False    False
# 8       False      False  False  False    False
# 9        True       True   True   True     True

# %%
people_np.fillna('Missing')
people_np.fillna(0)
people_np.isna()
# Out:
#    First_Name Last_Name   Age        Place        Married
# 0    Prasanna     Sahoo  30.0     Erlangen            Yes
# 1     Mamauni         0  30.0    Bangalore            Yes
# 2  nityananda     Sahoo  65.0  Bhubaneswar            Yes
# 3        Gugu         0  10.0        Nalco             No
# 4     Shradha     Sahoo  12.0            0              0
# 5           0     Sahoo  25.0      Sarikhi             No
# 6   Divynashu   Samanta  12.0     Hyderbad              0
# 7        Sibu     Sahoo   2.0      Kolkata  Not available
# 8        Debu     Sahoo   2.0        Nalco             No
# 9           0         0   0.0            0              0

# %%
people_np.dtypes
# Out:
# First_Name     object
# Last_Name      object
# Age           float64
# Place          object
# Married        object
# dtype: object

# %%
type(np.nan)
# Out:
# float

# %%
people_np['Age']= people_np['Age'].astype(float) # cant convert to int as NaN is float
 
people_np['Age'].dtypes
# Out:
# dtype('float64')

# %%
df['YearsCode'].unique()
# Out:
# array(['4', nan, '3', '16', '13', '6', '8', '12', '2', '5', '17', '10',
#        '14', '35', '7', 'Less than 1 year', '30', '9', '26', '40', '19',
#        '15', '20', '28', '25', '1', '22', '11', '33', '50', '41', '18',
#        '34', '24', '23', '42', '27', '21', '36', '32', '39', '38', '31',
#        '37', 'More than 50 years', '29', '44', '45', '48', '46', '43',
#        '47', '49'], dtype=object)

# %%
df['YearsCode'].replace({'Less than 1 year':0, 'More than 50 years':50}, inplace= True)

# %%
df['YearsCode']= df['YearsCode'].astype(float)

# %%
df['YearsCode'].mean()
# Out:
# 11.660681389160544

# %% [markdown]
# ### Referrence
#
# 1. https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.ExcelWriter.html [For excel write]

# %% [markdown]
# ## Youtube channel for laptop reparing
#
# 1. Laptex- youtube channel
# 2. https://www.youtube.com/watch?v=Nm14XYWq5bw  time-7.2sec for referrence
# 3. https://www.youtube.com/channel/UCXbA-gXbMAKbUKImRX-HBHg/playlists
# 4. https://www.youtube.com/user/taj569/videos
# 5. https://www.youtube.com/channel/UC_3wtPkmdCACTI0noYddCnA
# 6. https://www.youtube.com/user/harshadpatel26/videos
# 7. https://xlsxwriter.readthedocs.io/example_pandas_positioning.html [excel write]
