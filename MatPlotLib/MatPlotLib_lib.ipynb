# %%
insert Numpy as np
# Out:
#   File "<ipython-input-3-319cbff97ec4>", line 1
#     insert Numpy as np
#                ^
# SyntaxError: invalid syntax

# %%
cd C:\Users\psahoo\Documents\PJ\python\Python_Ref_Note\MatPlotLib
# Out:
# C:\Users\psahoo\Documents\PJ\python\Python_Ref_Note\MatPlotLib

# %%
pwd
# Out:
# 'C:\\Users\\psahoo\\Documents\\PJ\\python\\Python_Ref_Note\\MatPlotLib'

# %%
name='Sahoo'
score=10
print(f'Total score for {name} is {score}.')
print('Total score for %s is %s.' %(name, score))
x = [1,2,3,4,5,6]
y1 = [12,13,14,15,12,23]
y2 = [15,20,18,25,12,23]
# Out:
# Total score for Sahoo is 10.
# Total score for Sahoo is 10.

# %%
from matplotlib import pyplot as plt
print (plt.style.available)
plt.style.use('fivethirtyeight')
#plt.xkcd()

#plt.plot(x, y1,'k*-',linewidth=1, label= 'y1')  # 'k*-':-> oder is [colour][marker][linestyle] 
#plt.plot(x, y2,'r+--',linewidth=1,label = 'y2')

plt.plot(x, y1,linewidth=1, label= 'y1')
plt.plot(x, y2,'--',linewidth=1,label = 'y2')

plt.ylabel('Velocity',fontsize='10')
plt.xlabel('Time',fontsize='10')

plt.title('First Basic Plot')
plt.grid(True)
plt.legend()

# plt.show()
# Out:
# ['bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark-palette', 'seaborn-dark', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'seaborn', 'Solarize_Light2', 'tableau-colorblind10', '_classic_test']

# %%
import matplotlib.pyplot as plt
plt.figure(1)                # the first figure
plt.subplot(211)             # the first subplot in the first figure
plt.plot([1, 2, 3])
plt.subplot(212)             # the second subplot in the first figure
plt.plot([4, 5, 6])


plt.figure(2)                # a second figure
plt.plot([4, 5, 6])          # creates a subplot(111) by default

plt.figure(1)                # figure 1 current; subplot(212) still current
plt.subplot(211)             # make subplot(211) in figure1 current
plt.title('Easy as 1, 2, 3') # subplot 211 title

plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   del sys.path[0]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.axes()
plt.subplot(2,1,1)
plt.plot(x, y,'b*-',linewidth=5, markersize=12, fillstyle = 'none', label= 'Blue')
plt.plot(x, y,'g+--',linewidth=5, markersize=12, fillstyle = 'none',label = 'Green')
plt.ylabel('Velocity',fontsize='large')
plt.xlabel('Time',fontsize='large')
plt.yscale('linear')
plt.title('First Subplot',fontsize='15')
plt.grid(color='b',linewidth='1',linestyle='--')
plt.autoscale(enable=True, axis='both', tight=None)
plt.margins(0.04)
plt.legend(loc="best", ncol=2, shadow=True, title="Legend", fancybox=True, fontsize="10")
plt.suptitle('This is a somewhat long figure title', fontsize=12)
plt.savefig ('C:/Users/sahopra/Documents/figure.pdf', bbox_inches='tight', pad_inches=0.1)



plt.subplot(2,1,2 , facecolor=(0.3, 0.2, 0.1))
plt.plot(x, y, color='green', marker='o', linestyle='dashed',linewidth=2, markersize=12)
plt.subplots_adjust(top=1.95, bottom=0.03, left=0.020, right=0.95, hspace=0.15,wspace=0.35)
plt.text(2, 18, r'$\mu=100,\ \sigma=15$', color= 'w')
plt.title('Second Subplot',color = 'r',loc = 'center',fontsize=15)
# plt.axis([2,3,4,5])
plt.grid()
plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.show()
plt.savefig('C:/Users/sahopra/Documents/figure.pdf', bbox_inches='tight', pad_inches=0.1)

# %%
import matplotlib.pyplot as plt
plt.figure(1)                # the first figure
plt.subplot(211)             # the first subplot in the first figure
plt.plot([1, 2, 3])
plt.subplot(212)             # the second subplot in the first figure
plt.plot([4, 5, 6])
plt.show()
plt.figure(2)                # a second figure
plt.plot([4, 5, 6])          # creates a subplot(111) by default
plt.figure(1)                # figure 1 current; subplot(212) still current
plt.subplot(211)             # make subplot(211) in figure1 current
plt.title('Easy as 1, 2, 3') # subplot 211 title
# Out:
# Text(0.5,1,'Easy as 1, 2, 3')

# %%
import random
import matplotlib.pyplot as plt

## Step 1: Sample some sketches
# How many sketches to view - a random number from 2 to 20
n = random.randint(2, 20)
# Choose a random quickdraw category. (Check out https://quickdraw.withgoogle.com/data for an overview of categories)
category = random_category()
imgs = sample_images_of_category(n, category)

## Step 2: Choose the grid properties
######## Your changes should go here ###############
rows = 3
cols = 5
# The height and width of the whole grid, measured in inches.
height = 5
width = 16

## Step 3: Create the grid
grid = plt.subplots(rows, cols, figsize=(width, height))

## Step 4: Draw the sketches in the grid
draw_images_on_subplots(imgs, grid)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-67adaba610ff> in <module>()
#       6 n = random.randint(2, 20)
#       7 # Choose a random quickdraw category. (Check out https://quickdraw.withgoogle.com/data for an overview of categories)
# ----> 8 category = random_category()
#       9 imgs = sample_images_of_category(n, category)
#      10
#
# NameError: name 'random_category' is not defined
